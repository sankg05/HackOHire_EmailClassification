# %% [markdown]
# ## Importing libraries

# %%
# !pip install ydata_profiling pycaret

# %%
import pandas as pd
import numpy as np
from ydata_profiling import ProfileReport
import os
from pycaret.classification import setup, compare_models, pull, save_model

# %%
data = '/content/Train - Email Classification.csv'

# %%
transposed_data = list(map(list, zip(*data[3])))

# Create DataFrame
df = pd.DataFrame(transposed_data[1:], columns=transposed_data[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-30937f283c6a> in <cell line: 4>()
#       2
#       3 # Reshape the flattened data into a 2D array
# ----> 4 reshaped_data = np.array(flat_data).reshape(len(data), len(data[0]))
#       5
#       6 # Convert reshaped data into DataFrame
#
# ValueError: cannot reshape array of size 1 into shape (41,1)

# %%
df
# Out:
# Empty DataFrame
# Columns: [n]
# Index: []

# %% [markdown]
# ## Importing dataset

# %%
df = pd.read_csv('Book1.csv')
#df = df.read_csv('SourceData.csv', index_col = None)
#df = df.drop(columns=["length","key"] , axis=1)
df1 = pd.read_csv('Book3.csv')

# %%
transposed_df = df1.T

# %%
transposed_df = transposed_df.reset_index(drop=True)

# %% [markdown]
# ## Profile Report

# %%
profile_report = df1.profile_report()

# %%
profile_report
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.7.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-04-07 04:24:21.347862&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
profile_report1 = df.profile_report()
profile_report1
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.7.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-04-07 04:24:51.240749&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# ## Training and comparing models

# %%
# Out:
# Index(['mean_stft', 'var_stft', 'tempo', 'rms_mean', 'rms_var',
#        'centroid_mean', 'centroid_var', 'bandwidth_mean', 'bandwidth_var',
#        'rolloff_mean', 'rolloff_var', 'crossing_mean', 'crossing_var',
#        'harmonic_mean', 'harmonic_var', 'contrast_mean', 'contrast_var',
#        'key_name', 'scale', 'mfcc1_mean', 'mfcc1_var', 'mfcc2_mean',
#        'mfcc2_var', 'mfcc3_mean', 'mfcc3_var', 'mfcc4_mean', 'mfcc4_var',
#        'mfcc5_mean', 'mfcc5_var', 'mfcc6_mean', 'mfcc6_var', 'mfcc7_mean',
#        'mfcc7_var', 'mfcc8_mean', 'mfcc8_var', 'mfcc9_mean', 'mfcc9_var',
#        'mfcc10_mean', 'mfcc10_var', 'mfcc11_mean', 'mfcc11_var', 'mfcc12_mean',
#        'mfcc12_var', 'mfcc13_mean', 'mfcc13_var', 'mfcc14_mean', 'mfcc14_var',
#        'mfcc15_mean', 'mfcc15_var', 'mfcc16_mean', 'mfcc16_var', 'mfcc17_mean',
#        'mfcc17_var', 'mfcc18_mean', 'mfcc18_var', 'mfcc19_mean', 'mfcc19_var',
#        'mfcc20_mean', 'mfcc20_var', 'type', 'type_encoded'],
# ...

# %%
# Out:
# Index(['mean_stft', 'var_stft', 'tempo', 'rms_mean', 'rms_var',
#        'centroid_mean', 'centroid_var', 'bandwidth_mean', 'bandwidth_var',
#        'rolloff_mean', 'rolloff_var', 'crossing_mean', 'crossing_var',
#        'harmonic_mean', 'harmonic_var', 'contrast_mean', 'contrast_var',
#        'key_name', 'scale', 'mfcc1_mean', 'mfcc1_var', 'mfcc2_mean',
#        'mfcc2_var', 'mfcc3_mean', 'mfcc3_var', 'mfcc4_mean', 'mfcc4_var',
#        'mfcc5_mean', 'mfcc5_var', 'mfcc6_mean', 'mfcc6_var', 'mfcc7_mean',
#        'mfcc7_var', 'mfcc8_mean', 'mfcc8_var', 'mfcc9_mean', 'mfcc9_var',
#        'mfcc10_mean', 'mfcc10_var', 'mfcc11_mean', 'mfcc11_var', 'mfcc12_mean',
#        'mfcc12_var', 'mfcc13_mean', 'mfcc13_var', 'mfcc14_mean', 'mfcc14_var',
#        'mfcc15_mean', 'mfcc15_var', 'mfcc16_mean', 'mfcc16_var', 'mfcc17_mean',
#        'mfcc17_var', 'mfcc18_mean', 'mfcc18_var', 'mfcc19_mean', 'mfcc19_var',
#        'mfcc20_mean', 'mfcc20_var', 'type_encoded'],
#       dtype='object')

# %%
# Out:
#    mean_stft  var_stft       tempo  rms_mean   rms_var  centroid_mean  \
# 0   0.142304  0.077778  103.359375  0.057566  0.000004    3739.527596
# 1   0.142750  0.077922  103.359375  0.057221  0.000003    3746.376920
# 2   0.142896  0.077653  151.999081  0.057731  0.000003    3743.598783
# 3   0.143163  0.077370   93.963068  0.059096  0.000010    3680.965567
# 4   0.141628  0.077580  161.499023  0.060578  0.000004    3650.506417
#
#    centroid_var  bandwidth_mean  bandwidth_var  rolloff_mean  ...  mfcc2_mean  \
# 0   3931.221769     3794.751236     575.614691  19761.743824  ...   63.597620
# 1   4347.394874     3798.406668     535.044255  19760.579867  ...   63.668858
# 2   3893.958075     3795.604178     499.541038  19754.344383  ...   63.283980
# 3  10005.417040     3793.059524     846.988008  19744.866448  ...   67.031265
# 4   4429.289579     3761.474897     641.255619  19736.386191  ...   63.132830
#
#    mfcc2_var  mfcc3_mean  mfcc3_var  mfcc4_mean  mfcc4_var  mfcc5_mean  \
# ...

# %%
# Out:
# Selected Features: ['mfcc5_mean', 'bandwidth_mean', 'mfcc3_mean', 'mfcc7_mean', 'mfcc16_mean', 'harmonic_var', 'mfcc8_mean']

# %%
# Out:
# <style type="text/css">
# #T_de5eb_row9_col1, #T_de5eb_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_de5eb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de5eb_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_de5eb_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de5eb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_de5eb_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_de5eb_row0_col1" class="data row0 col1" >1864</td>
#     </tr>
#     <tr>
#       <th id="T_de5eb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_de5eb_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_de5eb_row1_col1" class="data row1 col1" >type_encoded</td>
#     </tr>
#     <tr>
# ...

# %%
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        monotonic_cst=None, random_state=1864, splitter='best')

# %%
# Out:
# <style type="text/css">
# #T_64ad2_row9_col1, #T_64ad2_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_64ad2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64ad2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_64ad2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64ad2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_64ad2_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_64ad2_row0_col1" class="data row0 col1" >7989</td>
#     </tr>
#     <tr>
#       <th id="T_64ad2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_64ad2_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_64ad2_row1_col1" class="data row1 col1" >type_encoded</td>
#     </tr>
#     <tr>
# ...

# %%
# Out:
# Accuracy:  0.46214745175655614
# Precision:  0.3736697888033915
# Recall:  0.4595827268316351
# F1 score:  0.4121273162798335
